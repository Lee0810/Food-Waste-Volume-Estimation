# %% [markdown]
# # 1.  Check GPU is ready?

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
print("Device Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# CUDA Available: True
# Device Name: NVIDIA GeForce RTX 2050

# %% [markdown]
# # 2.  Check Star Block is ready?

# %%
import sys, ultralytics, ultralytics.nn.modules.block as blk

print("Python exe:", sys.executable)
print("Ultralytics loaded from:", ultralytics.__file__)
print("block.py file:", blk.__file__)
print("'StarBlock' in __all__? ", "StarBlock" in blk.__all__)
# Out:
# Python exe: C:\Users\User\PycharmProjects\PythonProject\.venv39\Scripts\python.exe
# Ultralytics loaded from: C:\Users\User\PycharmProjects\PythonProject\.venv39\lib\site-packages\ultralytics\__init__.py
# block.py file: C:\Users\User\PycharmProjects\PythonProject\.venv39\lib\site-packages\ultralytics\nn\modules\block.py
# 'StarBlock' in __all__?  True

# %% [markdown]
# # 3. Train Model YOLOv8-cls (without neck module)

# %% [markdown]
# ## Category 1: Base Model (YOLOv8-cls without neck) + Star Block (Backbone)

# %%
from ultralytics import YOLO

ROOT = r"C:/Users/User/PycharmProjects/PythonProject/FYP/FoodWasteEstimator/food-101/food101_yolo"

# Use your modified yolov8n-cls.yaml (with StarBlock)
model_C1_SB = YOLO(r"C:/Users/User/PycharmProjects/PythonProject/.venv39/Lib/site-packages/ultralytics/cfg/models/v8/yolov8n-cls.yaml")
# Out:
# YOLOv8n-cls summary: 56 layers, 1,688,885 parameters, 1,688,885 gradients, 3.7 GFLOPs

# %%
print(model_C1_SB.model)
# Out:
# ClassificationModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (2): StarBlock(
#       (proj): Identity()
#       (dwconv1): ConvBN(
#         (conv): Conv2d(32, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=32, bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (f1): ConvBN(
#         (conv): Conv2d(32, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (f2): ConvBN(
#         (conv): Conv2d(32, 96, kernel_size=(1, 1), stride=(1, 1))
# ...

# %%
model_C1_SB.info().train(
    data=ROOT,
    epochs=30,
    imgsz=224,
    batch=32,
    device=0,
    workers=2,
    project=ROOT,
    name="runs_star",
)
print("\nStarBlock model training is complete.")
# Out:
# New https://pypi.org/project/ultralytics/8.3.232 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.146  Python-3.9.13 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %% [markdown]
# ## Category 1: Base Model (YOLOv8-cls without neck) + Cf2-Star (Backbone)

# %% [markdown]
# # CF2-Star in Backbone

# %%
from ultralytics import YOLO

ROOT = r"C:/Users/User/PycharmProjects/PythonProject/FYP/FoodWasteEstimator/food-101/food101_yolo"

# Use your modified yolov8n-cls.yaml (with C2f-StarBlock)
model_C1_C2fstarB = YOLO(r"C:/Users/User/PycharmProjects/PythonProject/.venv39/Lib/site-packages/ultralytics/cfg/models/v8/yolov8n-cls.yaml")
# Out:
# YOLOv8n-cls summary: 92 layers, 1,361,365 parameters, 1,361,365 gradients, 3.0 GFLOPs

# %%
print(model_C1_C2fstarB.model)
# Out:
# ClassificationModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
# ...

# %%
model_C1_C2fstarB.train(
    data=ROOT,
    epochs=30,
    imgsz=224,
    batch=32,
    device=0,
    workers=2,
    project=ROOT,
    name="runs_C2fstar",
)
print("\nC2fStarBlock model training is complete.")
# Out:
# New https://pypi.org/project/ultralytics/8.3.234 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.146  Python-3.9.13 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %% [markdown]
# # 4. Train Model YOLOv8-cls (with neck module)

# %% [markdown]
# ## Category 2: Base Model (YOLOv8-cls with neck) + Star Block (Backbone)

# %%
from ultralytics import YOLO

ROOT = r"C:/Users/User/PycharmProjects/PythonProject/FYP/FoodWasteEstimator/food-101/food101_yolo"

# Use your modified yolov8n-cls.yaml (with StarBlock)
model_n_starB = YOLO(r"C:/Users/User/PycharmProjects/PythonProject/.venv39/Lib/site-packages/ultralytics/cfg/models/v8/yolov8n-cls.yaml")
# Out:
# YOLOv8n-cls summary: 103 layers, 2,840,373 parameters, 2,840,373 gradients, 5.8 GFLOPs

# %%
print(model_n_starB.model)
# Out:
# ClassificationModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (2): StarBlock(
#       (proj): Identity()
#       (dwconv1): ConvBN(
#         (conv): Conv2d(32, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=32, bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (f1): ConvBN(
#         (conv): Conv2d(32, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (f2): ConvBN(
#         (conv): Conv2d(32, 96, kernel_size=(1, 1), stride=(1, 1))
# ...

# %%
model_n_starB.train(
    data=ROOT,
    epochs=50,
    imgsz=224,
    batch=32,
    device=0,
    workers=2,
    project=ROOT,
    name="runs_N_star",
)
print("\nStarBlock model with neck training is complete.")
# Out:
# New https://pypi.org/project/ultralytics/8.3.238 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.146  Python-3.9.13 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %% [markdown]
# ## Category 2: Base Model (YOLOv8-cls with neck) + Star Block (Backbone) + C2f-Star (Neck)

# %%
from ultralytics import YOLO

ROOT = r"C:/Users/User/PycharmProjects/PythonProject/FYP/FoodWasteEstimator/food-101/food101_yolo"

# Use your modified yolov8n-cls.yaml (with StarBlock and C2f-star)
model_n_cf2star = YOLO(r"C:/Users/User/PycharmProjects/PythonProject/.venv39/Lib/site-packages/ultralytics/cfg/models/v8/yolov8n-cls.yaml")
# Out:
# YOLOv8n-cls summary: 127 layers, 2,640,501 parameters, 2,640,501 gradients, 5.4 GFLOPs

# %%
print(model_n_cf2star)
# Out:
# YOLO(
#   (model): ClassificationModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (2): StarBlock(
#         (proj): Identity()
#         (dwconv1): ConvBN(
#           (conv): Conv2d(32, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (f1): ConvBN(
#           (conv): Conv2d(32, 96, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (f2): ConvBN(
# ...

# %%
model_n_cf2star.train(
    data=ROOT,
    epochs=30,
    imgsz=224,
    batch=32,
    device=0,
    workers=2,
    project=ROOT,
    name="runs_N_star_Cf2star",
)
print("\nStarBlock-cf2 model with neck training is complete.")
# Out:
# New https://pypi.org/project/ultralytics/8.3.239 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.146  Python-3.9.13 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...
