# %% [markdown]
# # Checking GPU is ready?

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())

# %% [markdown]
# # Setup GPU Reference link
#
# Youtube link:
#
# https://youtu.be/nATRPPZ5dGE?si=RdxSu172j4VYHgbQ

# %% [markdown]
# # Double check GPU setup

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA version:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# PyTorch version: 2.5.1+cu121
# CUDA version: 12.1
# CUDA available: True
# GPU Name: NVIDIA GeForce RTX 2050

# %% [markdown]
# # Check Dependency Library Version

# %%
import sys
import torch
import ultralytics
import numpy as np
import cv2
import matplotlib
import sklearn
import pandas
import torchvision

print("===== System & Software Versions =====")
print(f"Python: {sys.version}")
print(f"PyTorch: {torch.__version__}")
print(f"Torchvision: {torchvision.__version__}")
print(f"Ultralytics YOLO: {ultralytics.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version (PyTorch): {torch.version.cuda}")

print("\n===== Dependency Packages =====")
print(f"NumPy: {np.__version__}")
print(f"OpenCV: {cv2.__version__}")
print(f"Matplotlib: {matplotlib.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
print(f"Pandas: {pandas.__version__}")
# Out:
# ===== System & Software Versions =====
# Python: 3.9.13 (tags/v3.9.13:6de2ca5, May 17 2022, 16:36:42) [MSC v.1929 64 bit (AMD64)]
# PyTorch: 2.5.1+cu121
# Torchvision: 0.20.1+cu121
# Ultralytics YOLO: 8.3.146
# CUDA available: True
# CUDA version (PyTorch): 12.1
#
# ===== Dependency Packages =====
# NumPy: 1.24.4
# OpenCV: 4.11.0
# Matplotlib: 3.9.4
# Scikit-learn: 0.24.2
# Pandas: 2.3.3
